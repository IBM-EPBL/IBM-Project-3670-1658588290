# %%
test_dir=r'D:\VII SEMSETER\IBM\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\fruit-dataset\fruit-dataset\test'

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
model = tf.keras.models.load_model(r'D:\VII SEMSETER\IBM\Project Development Phase\Sprint 2\Model Building\fruit_datamodel.h5')

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 1686 images belonging to 6 classes.

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img(r"D:\VII SEMSETER\IBM\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\fruit-dataset\fruit-dataset\test\Corn_(maize)___healthy\9d7fe0ec-48b6-4b1e-83ea-391d53de37af___R.S_HL 8210 copy 3.jpg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x1F438F46FD0>

# %%
img=image.load_img(r"D:\VII SEMSETER\IBM\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\fruit-dataset\fruit-dataset\test\Corn_(maize)___healthy\9d7fe0ec-48b6-4b1e-83ea-391d53de37af___R.S_HL 8210 copy 3.jpg",target_size=(128,128))
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index=['Apple___Black_rot', 'Apple___healthy', 'Corn_(maize)___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Peach___Bacterial_spot', 'Peach___healthy']
index[y[0]]
# Out:
# 1/1 [==============================] - 7s 7s/step
# 'Corn_(maize)___Northern_Leaf_Blight'

# %%
model.evaluate(test_generator_1,steps=50)
# Out:
# 50/50 [==============================] - 26s 460ms/step - loss: 137.4763 - accuracy: 0.8530
# [137.47634887695312, 0.8529999852180481]
