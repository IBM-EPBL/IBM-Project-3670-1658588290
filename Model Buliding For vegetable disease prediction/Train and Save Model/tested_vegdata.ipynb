# %%
test_dir=r'D:\VII SEMSETER\IBM\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\Veg-dataset\Veg-dataset\test_set'

# %%
import tensorflow as tf 
from tensorflow import keras 
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
model = tf.keras.models.load_model(r'D:\VII SEMSETER\IBM\Project Development Phase\Sprint 2\Model Building\veg_datamodel.h5')

# %%
test_datagen_1=ImageDataGenerator(rescale=1)
test_generator_1=test_datagen_1.flow_from_directory(
    test_dir,
    target_size=(128,128),
    batch_size=20,
    class_mode='categorical'
)
# Out:
# Found 3416 images belonging to 9 classes.

# %%
import numpy as np
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image

# %%
img=image.load_img(r'D:\VII SEMSETER\IBM\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\Veg-dataset\Veg-dataset\test_set\Tomato___Bacterial_spot\b66ad55a-0bf2-4819-90f2-10d4206122e6___GCREC_Bact.Sp 3771.JPG')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x11934732AF0>

# %%
img=image.load_img(r'D:\VII SEMSETER\IBM\Fertilizers_Recommendation_ System_For_Disease_ Prediction\Dataset Plant Disease\Veg-dataset\Veg-dataset\test_set\Tomato___Bacterial_spot\b66ad55a-0bf2-4819-90f2-10d4206122e6___GCREC_Bact.Sp 3771.JPG', target_size=(128,128))
img
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1190933EAC0>

# %%
x=image.img_to_array(img)
x=np.expand_dims(x,axis=0)
y=np.argmax(model.predict(x),axis=1)
index = ['Pepper,_bell___Bacterial_spot','Pepper,_bell___healthy','Potato___Early_blight','Potato___Late_blight','Potato___healthy','Tomato___Bacterial_spot','Tomato___Late_blight','Tomato___Leaf_Mold','Tomato___Septoria_leaf_spot']
index[y[0]]
# Out:
# 1/1 [==============================] - 6s 6s/step
# 'Tomato___Septoria_leaf_spot'

# %%
model.evaluate(test_generator_1,steps=50)
# Out:
# 50/50 [==============================] - 35s 657ms/step - loss: 3073.5222 - accuracy: 0.2520
# [3073.522216796875, 0.25200000405311584]
